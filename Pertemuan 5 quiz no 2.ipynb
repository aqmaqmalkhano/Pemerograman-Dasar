# %% [markdown]
# <a href="https://colab.research.google.com/github/aqmaqmalkhano/Pemerograman-Dasar/blob/main/Pertemuan%205%20quiz%20no%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nama = "AQMAK"  # Ganti dengan nama Anda
counter = 0

while counter < 200:
    print(nama)
    counter += 1
# Out:
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# AQMAK
# ...
